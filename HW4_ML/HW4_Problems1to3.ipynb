# %% [markdown]
# # Problem 1

# %%
#Loading the required modules

import numpy as np
from scipy.spatial.distance import cdist
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import pandas as pd




#Defining our function 
def kmeans(x,k, no_of_iterations):
    idx = np.random.choice(len(x), k, replace=False)
    #Randomly choosing Centroids 
    centroids = x[idx, :] #Step 1
    
    #finding the distance between centroids and all the data points
    distances = cdist(x, centroids ,'euclidean') #Step 2
    
    #Centroid with the minimum Distance
    points = np.array([np.argmin(i) for i in distances]) #Step 3
    
    #Repeating the above steps for a defined number of iterations
    #Step 4
    centroFirst = []
    for _ in range(no_of_iterations): 
        centroids = []
        for idx in range(k):
            #Updating Centroids by taking mean of Cluster it belongs to
            temp_cent = x[points==idx].mean(axis=0) 
            centroids.append(temp_cent)
        
        centroids = np.vstack(centroids) #Updated Centroids 
        if(_ == 1):
          centroFirst = centroids
        distances = cdist(x, centroids ,'euclidean')
        points = np.array([np.argmin(i) for i in distances])
        
    return centroids, points, centroFirst

# %%
def calculate_WSS(points, kmax):
  sse = []
  for k in range(1, kmax+1):
    centroids, label ,centrofirst= kmeans(df,k,100)
    pred_clusters = label
    curr_sse = 0
    
    # calculate square of Euclidean distance of each point from its cluster center and add to current WSS
    for i in range(len(points)):
      curr_center = centroids[pred_clusters[i]]
      curr_sse += (points[i, 0] - curr_center[0]) ** 2 + (points[i, 1] - curr_center[1]) ** 2
      
    sse.append(curr_sse)
  return sse

# %%
data = pd.read_csv('data_kmeans_1.txt', sep=",", header=None)
pca = PCA(2)
 
#Transform the data
df = pca.fit_transform(data)

#Applying our function
centrolast, label, centrofirst = kmeans(df,7,1000)

#Visualize the results
fig = plt.figure(figsize=(15,10))
u_labels = np.unique(label)

for i in u_labels:
    plt.scatter(df[label == i , 0] , df[label == i , 1] , label = i)

plt.plot(centrolast[:,0], centrolast[:,1], 'bx', label='Last centroids')

plt.plot(centrofirst[:, 0], centrofirst[:, 1], 'gx', label='Init centroids')

plt.legend()
plt.show()

# %%
calculated_WSS = calculate_WSS(df,20)
print(len(calculated_WSS))
plt.plot(range(1,21), calculated_WSS, 'bx-')
plt.xlabel('k')
plt.ylabel('WSS')
plt.title('Elbow Method For Optimal k')
plt.grid()
plt.show()
# Out:
# 20

# %% [markdown]
# So the best K value for data_kmeans_1 is 5.

# %%
data = pd.read_csv('data_kmeans_1.txt', sep=",", header=None)
pca = PCA(2)
 
#Transform the data
df = pca.fit_transform(data)

#Applying our function
centrolast, label, centrofirst = kmeans(df,5,1000)

#Visualize the results

fig = plt.figure(figsize=(15,10))
u_labels = np.unique(label)

for i in u_labels:
    plt.scatter(df[label == i , 0] , df[label == i , 1] , label = i)

plt.plot(centrolast[:,0], centrolast[:,1], 'bx', label='Last centroids')

plt.plot(centrofirst[:, 0], centrofirst[:, 1], 'gx', label='Init centroids')

plt.legend()
plt.show()

# %%
data = pd.read_csv('data_kmeans_2.txt', sep=",", header=None)
pca = PCA(2)
 
#Transform the data
df = pca.fit_transform(data)

#Applying our function
centrolast, label, centrofirst= kmeans(df,7,1000)

#Visualize the results

fig = plt.figure(figsize=(15,10))
u_labels = np.unique(label)

for i in u_labels:
    plt.scatter(df[label == i , 0] , df[label == i , 1] , label = i)

plt.plot(centrolast[:,0], centrolast[:,1], 'bx', label='Last centroids')

plt.plot(centrofirst[:, 0], centrofirst[:, 1], 'gx', label='Init centroids')

plt.legend()
plt.show()

calculated_WSS = calculate_WSS(df,20)
plt.plot(range(1,21), calculated_WSS, 'bx-')
plt.xlabel('k')
plt.ylabel('WSS')
plt.title('Elbow Method For Optimal k')
plt.grid()
plt.show()

# %% [markdown]
# So the best K value for data_kmeans_2 is 5 too.

# %%
data = pd.read_csv('data_kmeans_2.txt', sep=",", header=None)
pca = PCA(2)
 
#Transform the data
df = pca.fit_transform(data)

#Applying our function
centrolast, label, centrofirst = kmeans(df,5,1000)

#Visualize the results
fig = plt.figure(figsize=(15,10))
u_labels = np.unique(label)

for i in u_labels:
    plt.scatter(df[label == i , 0] , df[label == i , 1] , label = i)

plt.plot(centrolast[:,0], centrolast[:,1], 'bx', label='Last centroids')

plt.plot(centrofirst[:, 0], centrofirst[:, 1], 'gx', label='Init centroids')

plt.legend()
plt.show()

# %%
data = pd.read_csv('data_kmeans_3.txt', sep=",", header=None)
pca = PCA(2)
 
#Transform the data
df = pca.fit_transform(data)

#Applying our function
centrolast, label, centrofirst = kmeans(df,5,1000)

#Visualize the results

fig = plt.figure(figsize=(15,10))
u_labels = np.unique(label)

for i in u_labels:
    plt.scatter(df[label == i , 0] , df[label == i , 1] , label = i)

plt.plot(centrolast[:,0], centrolast[:,1], 'bx', label='Last centroids')

plt.plot(centrofirst[:, 0], centrofirst[:, 1], 'gx', label='Init centroids')

plt.legend()
plt.show()

calculated_WSS = calculate_WSS(df,20)
plt.plot(range(1,21), calculated_WSS, 'bx-')
plt.xlabel('k')
plt.ylabel('WSS')
plt.title('Elbow Method For Optimal k')
plt.grid()
plt.show()

# %% [markdown]
# and for data_kmeans_3 the best k value is 3.

# %%
data = pd.read_csv('data_kmeans_3.txt', sep=",", header=None)
pca = PCA(2)
 
#Transform the data
df = pca.fit_transform(data)

#Applying our function
centrolast, label, centrofirst= kmeans(df,3,1000)

fig = plt.figure(figsize=(15,10))
u_labels = np.unique(label)

for i in u_labels:
    plt.scatter(df[label == i , 0] , df[label == i , 1] , label = i)

plt.plot(centrolast[:,0], centrolast[:,1], 'bx', label='Last centroids')

plt.plot(centrofirst[:, 0], centrofirst[:, 1], 'gx', label='Init centroids')

plt.legend()
plt.show()

# %% [markdown]
# # Problem 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
  
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA

X = pd.read_csv('Compound.txt', sep="\t", header=None)
X = X.drop(X.columns[2], axis=1)

# Scaling the data to bring all the attributes to a comparable level
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
  
# Normalizing the data so that 
# the data approximately follows a Gaussian distribution
X_normalized = normalize(X_scaled)
  
# Converting the numpy array into a pandas DataFrame
X_normalized = pd.DataFrame(X_normalized)

pca = PCA(n_components = 2)
X_principal = pca.fit_transform(X_normalized)
X_principal = pd.DataFrame(X_principal)


db_default = DBSCAN(eps = 0.04, min_samples = 5).fit(X_principal)
labels = db_default.labels_

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pylab

X = pd.read_csv('Compound.txt', sep="\t", header=None)
x = X[0]
y = X[1]
label = labels

fig = plt.figure(figsize=(8,8))
plt.scatter(x, y, c=label, cmap=pylab.cm.cool)

cb = plt.colorbar()
loc = np.arange(0,max(label),max(label)/float(len(colors)))
cb.set_ticks(loc)
cb.set_ticklabels(colors)

# %%
import numpy as np
from sklearn import metrics

def purity_score(y_true, y_pred):
    # compute contingency matrix (also called confusion matrix)
    contingency_matrix = metrics.cluster.contingency_matrix(y_true, y_pred)
    # return purity
    return np.sum(np.amax(contingency_matrix, axis=0)) / np.sum(contingency_matrix)

# %%
purity_score(X[2], labels)
# Out:
# 0.8446115288220551

# %% [markdown]
# D31

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
  
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA

X = pd.read_csv('D31.txt', sep="\t", header=None)
X = X.drop(X.columns[2], axis=1)

# Scaling the data to bring all the attributes to a comparable level
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
  
# Normalizing the data so that 
# the data approximately follows a Gaussian distribution
# X_normalized = normalize(X_scaled)
  
# Converting the numpy array into a pandas DataFrame
# X_normalized = pd.DataFrame(X_normalized)

pca = PCA(n_components = 2)
X_principal = X
# X_principal = pca.fit_transform(X_normalized)
# X_principal = pd.DataFrame(X_principal)


db_default = DBSCAN(eps = 0.5, min_samples = 7).fit(X_principal)
labels = db_default.labels_

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pylab

X = pd.read_csv('D31.txt', sep="\t", header=None)
x = X[0]
y = X[1]
label = labels

fig = plt.figure(figsize=(8,8))
plt.scatter(x, y, c=label, cmap=pylab.cm.jet_r)

# %%
purity_score(X[2], labels)
# Out:
# 0.8548387096774194

# %% [markdown]
# spiral

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
  
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA

X = pd.read_csv('spiral.txt', sep="\t", header=None)
X = X.drop(X.columns[2], axis=1)

db_default = DBSCAN(eps = 3.5, min_samples = 5).fit(X)
labels = db_default.labels_

# %%
# Scaling the data to bring all the attributes to a comparable level
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
  
# Normalizing the data so that 
# the data approximately follows a Gaussian distribution
X_normalized = normalize(X_scaled)
  
# Converting the numpy array into a pandas DataFrame
X_normalized = pd.DataFrame(X_normalized)

pca = PCA(n_components = 2)

X_principal = pca.fit_transform(X_normalized)
X_principal = pd.DataFrame(X_principal)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pylab

X = pd.read_csv('spiral.txt', sep="\t", header=None)
x = X[0]
y = X[1]
label = labels

fig = plt.figure(figsize=(8,8))
plt.scatter(x, y, c=label, cmap=pylab.cm.jet_r)

# %%
purity_score(X[2], labels)
# Out:
# 1.0

# %% [markdown]
# # Problem 3

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import numpy as np
from sklearn.cluster import AgglomerativeClustering

X = pd.read_excel (r'data_h.xlsx') 
df = pd.DataFrame(X)

import scipy.cluster.hierarchy as shc

plt.figure(figsize=(10, 7))
plt.title("Customer Dendograms")
dend = shc.dendrogram(shc.linkage(X, method='ward'))

# %% [markdown]
# Bottom Up

# %%
from sklearn.cluster import AgglomerativeClustering


fig, axs = plt.subplots(2,4, figsize=(15, 6))


results = []
num = 0
for i in range(2,9):
  cluster = AgglomerativeClustering(n_clusters=i, affinity='euclidean', linkage='ward')
  cluster.fit_predict(X)
  results.append(cluster)

for i in range (2):
  for j in range (4):
    if num < 7:
      axs[i][j].scatter(X.iloc[:,0], X.iloc[:,1], c=results[num].labels_, cmap='rainbow')
      num = num + 1

# %%
from sklearn.cluster import AgglomerativeClustering


fig, axs = plt.subplots(2,4, figsize=(15, 6))


results = []
num = 0
for i in range(2,9):
  cluster = AgglomerativeClustering(n_clusters=i, affinity='euclidean', linkage='single')
  cluster.fit_predict(X)
  results.append(cluster)

for i in range (2):
  for j in range (4):
    if num < 7:
      axs[i][j].scatter(X.iloc[:,0], X.iloc[:,1], c=results[num].labels_, cmap='rainbow')
      num = num + 1

# %%
from sklearn.cluster import AgglomerativeClustering


fig, axs = plt.subplots(2,4, figsize=(15, 6))


results = []
num = 0
for i in range(2,9):
  cluster = AgglomerativeClustering(n_clusters=i, affinity='euclidean', linkage='complete')
  cluster.fit_predict(X)
  results.append(cluster)

for i in range (2):
  for j in range (4):
    if num < 7:
      axs[i][j].scatter(X.iloc[:,0], X.iloc[:,1], c=results[num].labels_, cmap='rainbow')
      num = num + 1

# %% [markdown]
# Top Down

# %%
from sklearn.cluster import AgglomerativeClustering


fig, axs = plt.subplots(2,4, figsize=(15, 6))


results = []
num = 6
for i in range(2,9):
  cluster = AgglomerativeClustering(n_clusters=i, affinity='euclidean', linkage='ward')
  cluster.fit_predict(X)
  results.append(cluster)


for i in range (2):
  for j in range (4):
    if num > -1:
      axs[i][j].scatter(X.iloc[:,0], X.iloc[:,1], c=results[num].labels_, cmap='rainbow')
      num = num - 1

# %%
from sklearn.cluster import AgglomerativeClustering


fig, axs = plt.subplots(2,4, figsize=(15, 6))


results = []
num = 6
for i in range(2,9):
  cluster = AgglomerativeClustering(n_clusters=i, affinity='euclidean', linkage='single')
  cluster.fit_predict(X)
  results.append(cluster)


for i in range (2):
  for j in range (4):
    if num > -1:
      axs[i][j].scatter(X.iloc[:,0], X.iloc[:,1], c=results[num].labels_, cmap='rainbow')
      num = num - 1

# %%
from sklearn.cluster import AgglomerativeClustering


fig, axs = plt.subplots(2,4, figsize=(15, 6))


results = []
num = 6
for i in range(2,9):
  cluster = AgglomerativeClustering(n_clusters=i, affinity='euclidean', linkage='complete')
  cluster.fit_predict(X)
  results.append(cluster)


for i in range (2):
  for j in range (4):
    if num > -1:
      axs[i][j].scatter(X.iloc[:,0], X.iloc[:,1], c=results[num].labels_, cmap='rainbow')
      num = num - 1
